# %% [markdown]
# <a href="https://colab.research.google.com/github/s-mahapule/data-analytics-nptel/blob/main/Python_basics_nptel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp

# %%
url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
df.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]>

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.dtypes
# Out:
# country       object
# year           int64
# pop          float64
# continent     object
# lifeExp      float64
# gdpPercap    float64
# dtype: object

# %%
country_df = df['country']

# %%
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
country_df.tail()
# Out:
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
subset = df[['country','pop','continent']]
subset.head()
# Out:
#        country         pop continent
# 0  Afghanistan   8425333.0      Asia
# 1  Afghanistan   9240934.0      Asia
# 2  Afghanistan  10267083.0      Asia
# 3  Afghanistan  11537966.0      Asia
# 4  Afghanistan  13079460.0      Asia

# %%
df.loc[0]
# Out:
# country      Afghanistan
# year                1952
# pop            8425333.0
# continent           Asia
# lifeExp           28.801
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.tail(n=1)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.loc[[0,99,999]]
# Out:
#          country  year         pop continent  lifeExp    gdpPercap
# 0    Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 99    Bangladesh  1967  62821884.0      Asia   43.453   721.186086
# 999     Mongolia  1967   1149500.0      Asia   51.253  1226.041130

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# year                1952
# pop            8425333.0
# continent           Asia
# lifeExp           28.801
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# year               2007
# pop          12311143.0
# continent        Africa
# lifeExp          43.487
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.iloc[[0,99,999]]
# Out:
#          country  year         pop continent  lifeExp    gdpPercap
# 0    Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 99    Bangladesh  1967  62821884.0      Asia   43.453   721.186086
# 999     Mongolia  1967   1149500.0      Asia   51.253  1226.041130

# %%
#subsetting cols
subset = df.loc[:,['year','pop']]
subset.head()
# Out:
#    year         pop
# 0  1952   8425333.0
# 1  1957   9240934.0
# 2  1962  10267083.0
# 3  1967  11537966.0
# 4  1972  13079460.0

# %%
subset = df.iloc[:,[2,4,-1]]
subset.head()
# Out:
#           pop  lifeExp   gdpPercap
# 0   8425333.0   28.801  779.445314
# 1   9240934.0   30.332  820.853030
# 2  10267083.0   31.997  853.100710
# 3  11537966.0   34.020  836.197138
# 4  13079460.0   36.088  739.981106

# %%
small_range = list(range(5))
subset = df.iloc[:,small_range]
subset.head()
# Out:
#        country  year         pop continent  lifeExp
# 0  Afghanistan  1952   8425333.0      Asia   28.801
# 1  Afghanistan  1957   9240934.0      Asia   30.332
# 2  Afghanistan  1962  10267083.0      Asia   31.997
# 3  Afghanistan  1967  11537966.0      Asia   34.020
# 4  Afghanistan  1972  13079460.0      Asia   36.088

# %%
df.loc[40,'country']
# Out:
# 'Angola'

# %%
df.iloc[[0,99,999],[0,3,5]]
# Out:
#          country continent    gdpPercap
# 0    Afghanistan      Asia   779.445314
# 99    Bangladesh      Asia   721.186086
# 999     Mongolia      Asia  1226.041130

# %%
df.loc[[0,99,999],['country','gdpPercap','pop']]
# Out:
#          country    gdpPercap         pop
# 0    Afghanistan   779.445314   8425333.0
# 99    Bangladesh   721.186086  62821884.0
# 999     Mongolia  1226.041130   1149500.0

# %%
df.loc[10:13,['country','gdpPercap','pop']]
# Out:
#         country    gdpPercap         pop
# 10  Afghanistan   726.734055  25268405.0
# 11  Afghanistan   974.580338  31889923.0
# 12      Albania  1601.056136   1282697.0
# 13      Albania  1942.284244   1476505.0

# %%
print(df.groupby('year')['lifeExp'].mean())
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
multi_group_var = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()

# %%
print(multi_group_var)
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
flat = multi_group_var.reset_index()

# %%
print(flat.head())
# Out:
#    year continent    lifeExp     gdpPercap
# 0  1952    Africa  39.135500   1252.572466
# 1  1952  Americas  53.279840   4079.062552
# 2  1952      Asia  46.314394   5195.484004
# 3  1952    Europe  64.408500   5661.057435
# 4  1952   Oceania  69.255000  10298.085650

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
global_lifeexp = df.groupby('year')['lifeExp'].mean()
global_lifeexp.plot()
# Out:
# <Axes: xlabel='year'>
